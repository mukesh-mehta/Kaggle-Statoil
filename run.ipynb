# %%
from processing import pre_processing_1, pre_processing_2
from train import train_vgg_mobile, train_vgg16, train_vgg19, train_basic
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
test = pd.read_json("data/test.json")

# %%
X_train, X_angle,target_train, X_test, X_test_angle= pre_processing_1()

# %%
K=7
pred_vgg_mobile = train_vgg_mobile(X_train,X_angle,target_train,X_test,X_test_angle,K)

submission = pd.DataFrame()
submission['id']=test['id']
submission['is_iceberg']=pred_vgg_mobile
submission.to_csv('vgg_mobile.csv', index=False)
# Out:
# Running vgg and mobilenet
#
# ===================FOLD= 1
# gpu memory cleaned
# /home/mukesh/Desktop/Kaggle_live/Statoil/codes/models.py:77: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("de...)`
#   model = Model(input=[base_model.input, input_2], output=predictions)
# Epoch 1/100
# 24/24 [==============================] - 26s - loss: 0.7711 - acc: 0.5497 - val_loss: 0.6774 - val_acc: 0.5565
# Epoch 2/100
# 24/24 [==============================] - 14s - loss: 0.6371 - acc: 0.6219 - val_loss: 0.5445 - val_acc: 0.5913
# Epoch 3/100
# 24/24 [==============================] - 13s - loss: 0.6756 - acc: 0.6115 - val_loss: 0.6840 - val_acc: 0.5304
# Epoch 4/100
# 24/24 [==============================] - 13s - loss: 0.6528 - acc: 0.6162 - val_loss: 0.6717 - val_acc: 0.5826
# Epoch 5/100
# 24/24 [==============================] - 14s - loss: 0.5732 - acc: 0.6868 - val_loss: 0.4145 - val_acc: 0.8174
# Epoch 6/100
# ...

# %%
K=5
pred_vgg16 = train_vgg16(X_train,X_angle,target_train,X_test,X_test_angle,K)

submission = pd.DataFrame()
submission['id']=test['id']
submission['is_iceberg']=pred_vgg16
submission.to_csv('vgg_16.csv', index=False)
# Out:
# Running vgg16
#
# ===================FOLD= 1
# gpu memory cleaned
# /home/mukesh/Desktop/Kaggle_live/Statoil/codes/models.py:30: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("de...)`
#   model = Model(input=[base_model.input, input_2], output=predictions)
# Epoch 1/100
# 24/24 [==============================] - 17s - loss: 0.7808 - acc: 0.5417 - val_loss: 0.6951 - val_acc: 0.5311
# Epoch 2/100
# 24/24 [==============================] - 10s - loss: 0.7395 - acc: 0.5287 - val_loss: 0.6973 - val_acc: 0.4689
# Epoch 3/100
# 24/24 [==============================] - 10s - loss: 0.7009 - acc: 0.5326 - val_loss: 0.6589 - val_acc: 0.5621
# Epoch 4/100
# 24/24 [==============================] - 10s - loss: 0.6912 - acc: 0.5280 - val_loss: 0.6331 - val_acc: 0.5497
# Epoch 5/100
# 24/24 [==============================] - 10s - loss: 0.7056 - acc: 0.5202 - val_loss: 0.6780 - val_acc: 0.6398
# Epoch 6/100
# ...

# %%
k=5
pred_vgg19 = train_vgg19(X_train,X_angle,target_train,X_test,X_test_angle,K)

submission = pd.DataFrame()
submission['id']=test['id']
submission['is_iceberg']=pred_vgg19
submission.to_csv('vgg_19.csv', index=False)
# Out:
# Running vgg19
#
# ===================FOLD= 1
# gpu memory cleaned
# /home/mukesh/Desktop/Kaggle_live/Statoil/codes/models.py:53: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("de...)`
#   model = Model(input=[base_model.input, input_2], output=predictions)
# Epoch 1/100
# 24/24 [==============================] - 17s - loss: 0.7365 - acc: 0.5800 - val_loss: 0.7116 - val_acc: 0.5311
# Epoch 2/100
# 24/24 [==============================] - 10s - loss: 0.6393 - acc: 0.6172 - val_loss: 0.4958 - val_acc: 0.7453
# Epoch 3/100
# 24/24 [==============================] - 10s - loss: 0.5927 - acc: 0.6493 - val_loss: 0.5000 - val_acc: 0.7298
# Epoch 4/100
# 24/24 [==============================] - 10s - loss: 0.5178 - acc: 0.7250 - val_loss: 0.3981 - val_acc: 0.8230
# Epoch 5/100
# 24/24 [==============================] - 10s - loss: 0.4323 - acc: 0.8076 - val_loss: 0.3344 - val_acc: 0.8602
# Epoch 6/100
# ...
